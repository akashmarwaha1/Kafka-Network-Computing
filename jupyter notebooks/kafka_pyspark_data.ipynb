# %%
#importing the jar files and SparkSession

from pyspark.sql import SparkSession
import pyspark
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--jars ./abris_2.12-3.2.0.jar --packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.2.0 pyspark-shell'

# %%
# Creating the SparkSession

spark = SparkSession.builder.appName('spark_app')\
.getOrCreate()
print(spark)
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/spark-3.2.0-bin-hadoop3.2/jars/spark-unsafe_2.12-3.2.0.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# :: loading settings :: url = jar:file:/usr/local/spark-3.2.0-bin-hadoop3.2/jars/ivy-2.5.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/jovyan/.ivy2/cache
# The jars for the packages stored in: /home/jovyan/.ivy2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-0c2eaadc-a74a-47a1-92e2-fdeddeffa564;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.2.0 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.2.0 in central
# 	found org.apache.kafka#kafka-clients;2.8.0 in central
# 	found org.lz4#lz4-java;1.7.1 in central
# 	found org.xerial.snappy#snappy-java;1.1.8.4 in central
# 	found org.slf4j#slf4j-api;1.7.30 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.1 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# 	found org.apache.hadoop#hadoop-client-api;3.3.1 in central
# 	found org.apache.htrace#htrace-core4;4.1.0-incubating in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.apache.commons#commons-pool2;2.6.2 in central
# :: resolution report :: resolve 1334ms :: artifacts dl 43ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	org.apache.commons#commons-pool2;2.6.2 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.3.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.3.1 from central in [default]
# 	org.apache.htrace#htrace-core4;4.1.0-incubating from central in [default]
# 	org.apache.kafka#kafka-clients;2.8.0 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.2.0 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.2.0 from central in [default]
# 	org.lz4#lz4-java;1.7.1 from central in [default]
# 	org.slf4j#slf4j-api;1.7.30 from central in [default]
# 	org.spark-project.spark#unused;1.0.0 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.8.4 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   13  |   0   |   0   |   0   ||   13  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-0c2eaadc-a74a-47a1-92e2-fdeddeffa564
# 	confs: [default]
# 	0 artifacts copied, 13 already retrieved (0kB/31ms)
# 21/11/21 23:01:26 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# 21/11/21 23:01:27 WARN DependencyUtils: Local jar /home/jovyan/abris_2.12-3.2.0.jar does not exist, skipping.
# 21/11/21 23:01:27 INFO SparkContext: Running Spark version 3.2.0
# 21/11/21 23:01:27 INFO ResourceUtils: ==============================================================
# 21/11/21 23:01:27 INFO ResourceUtils: No custom resources configured for spark.driver.
# 21/11/21 23:01:27 INFO ResourceUtils: ==============================================================
# 21/11/21 23:01:27 INFO SparkContext: Submitted application: spark_app
# 21/11/21 23:01:27 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 21/11/21 23:01:27 INFO ResourceProfile: Limiting resource is cpu
# 21/11/21 23:01:27 INFO ResourceProfileManager: Added ResourceProfile id: 0
# 21/11/21 23:01:27 INFO SecurityManager: Changing view acls to: jovyan
# 21/11/21 23:01:27 INFO SecurityManager: Changing modify acls to: jovyan
# 21/11/21 23:01:27 INFO SecurityManager: Changing view acls groups to:
# 21/11/21 23:01:27 INFO SecurityManager: Changing modify acls groups to:
# 21/11/21 23:01:27 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(jovyan); groups with view permissions: Set(); users  with modify permissions: Set(jovyan); groups with modify permissions: Set()
# 21/11/21 23:01:28 INFO Utils: Successfully started service 'sparkDriver' on port 40269.
# 21/11/21 23:01:28 INFO SparkEnv: Registering MapOutputTracker
# 21/11/21 23:01:28 INFO SparkEnv: Registering BlockManagerMaster
# 21/11/21 23:01:28 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 21/11/21 23:01:28 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 21/11/21 23:01:28 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 21/11/21 23:01:28 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-9fa5f140-4aa4-4e88-8ee3-1f98a074bc38
# 21/11/21 23:01:28 INFO MemoryStore: MemoryStore started with capacity 434.4 MiB
# 21/11/21 23:01:28 INFO SparkEnv: Registering OutputCommitCoordinator
# 21/11/21 23:01:29 INFO Utils: Successfully started service 'SparkUI' on port 4040.
# 21/11/21 23:01:29 INFO SparkUI: Bound SparkUI to 0.0.0.0, and started at http://pyspark:4040
# 21/11/21 23:01:29 ERROR SparkContext: Failed to add file:/home/jovyan/abris_2.12-3.2.0.jar to Spark environment
# java.io.FileNotFoundException: Jar /home/jovyan/abris_2.12-3.2.0.jar not found
# 	at org.apache.spark.SparkContext.addLocalJarFile$1(SparkContext.scala:1935)
# 	at org.apache.spark.SparkContext.addJar(SparkContext.scala:1990)
# 	at org.apache.spark.SparkContext.$anonfun$new$12(SparkContext.scala:503)
# 	at org.apache.spark.SparkContext.$anonfun$new$12$adapted(SparkContext.scala:503)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.SparkContext.<init>(SparkContext.scala:503)
# 	at org.apache.spark.api.java.JavaSparkContext.<init>(JavaSparkContext.scala:58)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:62)
# 	at java.base/jdk.internal.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# 	at java.base/java.lang.reflect.Constructor.newInstance(Constructor.java:490)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:247)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:238)
# 	at py4j.commands.ConstructorCommand.invokeConstructor(ConstructorCommand.java:80)
# 	at py4j.commands.ConstructorCommand.execute(ConstructorCommand.java:69)
# 	at py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)
# 	at py4j.ClientServerConnection.run(ClientServerConnection.java:106)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# 21/11/21 23:01:29 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.2.0.jar at spark://pyspark:40269/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.2.0.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.2.0.jar at spark://pyspark:40269/jars/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.2.0.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.kafka_kafka-clients-2.8.0.jar at spark://pyspark:40269/jars/org.apache.kafka_kafka-clients-2.8.0.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.0.jar at spark://pyspark:40269/jars/com.google.code.findbugs_jsr305-3.0.0.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.commons_commons-pool2-2.6.2.jar at spark://pyspark:40269/jars/org.apache.commons_commons-pool2-2.6.2.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.spark-project.spark_unused-1.0.0.jar at spark://pyspark:40269/jars/org.spark-project.spark_unused-1.0.0.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-client-runtime-3.3.1.jar at spark://pyspark:40269/jars/org.apache.hadoop_hadoop-client-runtime-3.3.1.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.lz4_lz4-java-1.7.1.jar at spark://pyspark:40269/jars/org.lz4_lz4-java-1.7.1.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar at spark://pyspark:40269/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.30.jar at spark://pyspark:40269/jars/org.slf4j_slf4j-api-1.7.30.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-client-api-3.3.1.jar at spark://pyspark:40269/jars/org.apache.hadoop_hadoop-client-api-3.3.1.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/org.apache.htrace_htrace-core4-4.1.0-incubating.jar at spark://pyspark:40269/jars/org.apache.htrace_htrace-core4-4.1.0-incubating.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO SparkContext: Added JAR file:///home/jovyan/.ivy2/jars/commons-logging_commons-logging-1.1.3.jar at spark://pyspark:40269/jars/commons-logging_commons-logging-1.1.3.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.2.0.jar at file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.2.0.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.2.0.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.spark_spark-sql-kafka-0-10_2.12-3.2.0.jar
# 21/11/21 23:01:29 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.2.0.jar at file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.2.0.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.2.0.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.2.0.jar
# 21/11/21 23:01:29 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.kafka_kafka-clients-2.8.0.jar at file:///home/jovyan/.ivy2/jars/org.apache.kafka_kafka-clients-2.8.0.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.kafka_kafka-clients-2.8.0.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.kafka_kafka-clients-2.8.0.jar
# 21/11/21 23:01:29 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.0.jar at file:///home/jovyan/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.0.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO Utils: Copying /home/jovyan/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.0.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/com.google.code.findbugs_jsr305-3.0.0.jar
# 21/11/21 23:01:29 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.commons_commons-pool2-2.6.2.jar at file:///home/jovyan/.ivy2/jars/org.apache.commons_commons-pool2-2.6.2.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.commons_commons-pool2-2.6.2.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.commons_commons-pool2-2.6.2.jar
# 21/11/21 23:01:29 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.spark-project.spark_unused-1.0.0.jar at file:///home/jovyan/.ivy2/jars/org.spark-project.spark_unused-1.0.0.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.spark-project.spark_unused-1.0.0.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.spark-project.spark_unused-1.0.0.jar
# 21/11/21 23:01:29 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-client-runtime-3.3.1.jar at file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-client-runtime-3.3.1.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-client-runtime-3.3.1.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.hadoop_hadoop-client-runtime-3.3.1.jar
# 21/11/21 23:01:29 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.lz4_lz4-java-1.7.1.jar at file:///home/jovyan/.ivy2/jars/org.lz4_lz4-java-1.7.1.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.lz4_lz4-java-1.7.1.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.lz4_lz4-java-1.7.1.jar
# 21/11/21 23:01:29 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar at file:///home/jovyan/.ivy2/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.xerial.snappy_snappy-java-1.1.8.4.jar
# 21/11/21 23:01:29 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.30.jar at file:///home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.30.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.30.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.slf4j_slf4j-api-1.7.30.jar
# 21/11/21 23:01:29 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-client-api-3.3.1.jar at file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-client-api-3.3.1.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-client-api-3.3.1.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.hadoop_hadoop-client-api-3.3.1.jar
# 21/11/21 23:01:29 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/org.apache.htrace_htrace-core4-4.1.0-incubating.jar at file:///home/jovyan/.ivy2/jars/org.apache.htrace_htrace-core4-4.1.0-incubating.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO Utils: Copying /home/jovyan/.ivy2/jars/org.apache.htrace_htrace-core4-4.1.0-incubating.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.htrace_htrace-core4-4.1.0-incubating.jar
# 21/11/21 23:01:29 INFO SparkContext: Added file file:///home/jovyan/.ivy2/jars/commons-logging_commons-logging-1.1.3.jar at file:///home/jovyan/.ivy2/jars/commons-logging_commons-logging-1.1.3.jar with timestamp 1637535687518
# 21/11/21 23:01:29 INFO Utils: Copying /home/jovyan/.ivy2/jars/commons-logging_commons-logging-1.1.3.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/commons-logging_commons-logging-1.1.3.jar
# 21/11/21 23:01:30 INFO Executor: Starting executor ID driver on host pyspark
# 21/11/21 23:01:30 INFO Executor: Fetching file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.2.0.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: /home/jovyan/.ivy2/jars/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.2.0.jar has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.2.0.jar
# 21/11/21 23:01:30 INFO Executor: Fetching file:///home/jovyan/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.2.0.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: /home/jovyan/.ivy2/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.2.0.jar has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.spark_spark-sql-kafka-0-10_2.12-3.2.0.jar
# 21/11/21 23:01:30 INFO Executor: Fetching file:///home/jovyan/.ivy2/jars/org.spark-project.spark_unused-1.0.0.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: /home/jovyan/.ivy2/jars/org.spark-project.spark_unused-1.0.0.jar has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.spark-project.spark_unused-1.0.0.jar
# 21/11/21 23:01:30 INFO Executor: Fetching file:///home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.30.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: /home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.30.jar has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.slf4j_slf4j-api-1.7.30.jar
# 21/11/21 23:01:30 INFO Executor: Fetching file:///home/jovyan/.ivy2/jars/org.apache.commons_commons-pool2-2.6.2.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: /home/jovyan/.ivy2/jars/org.apache.commons_commons-pool2-2.6.2.jar has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.commons_commons-pool2-2.6.2.jar
# 21/11/21 23:01:30 INFO Executor: Fetching file:///home/jovyan/.ivy2/jars/org.apache.kafka_kafka-clients-2.8.0.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: /home/jovyan/.ivy2/jars/org.apache.kafka_kafka-clients-2.8.0.jar has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.kafka_kafka-clients-2.8.0.jar
# 21/11/21 23:01:30 INFO Executor: Fetching file:///home/jovyan/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.0.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: /home/jovyan/.ivy2/jars/com.google.code.findbugs_jsr305-3.0.0.jar has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/com.google.code.findbugs_jsr305-3.0.0.jar
# 21/11/21 23:01:30 INFO Executor: Fetching file:///home/jovyan/.ivy2/jars/org.lz4_lz4-java-1.7.1.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: /home/jovyan/.ivy2/jars/org.lz4_lz4-java-1.7.1.jar has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.lz4_lz4-java-1.7.1.jar
# 21/11/21 23:01:30 INFO Executor: Fetching file:///home/jovyan/.ivy2/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: /home/jovyan/.ivy2/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.xerial.snappy_snappy-java-1.1.8.4.jar
# 21/11/21 23:01:30 INFO Executor: Fetching file:///home/jovyan/.ivy2/jars/org.apache.htrace_htrace-core4-4.1.0-incubating.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: /home/jovyan/.ivy2/jars/org.apache.htrace_htrace-core4-4.1.0-incubating.jar has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.htrace_htrace-core4-4.1.0-incubating.jar
# 21/11/21 23:01:30 INFO Executor: Fetching file:///home/jovyan/.ivy2/jars/commons-logging_commons-logging-1.1.3.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: /home/jovyan/.ivy2/jars/commons-logging_commons-logging-1.1.3.jar has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/commons-logging_commons-logging-1.1.3.jar
# 21/11/21 23:01:30 INFO Executor: Fetching file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-client-api-3.3.1.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: /home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-client-api-3.3.1.jar has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.hadoop_hadoop-client-api-3.3.1.jar
# 21/11/21 23:01:30 INFO Executor: Fetching file:///home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-client-runtime-3.3.1.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: /home/jovyan/.ivy2/jars/org.apache.hadoop_hadoop-client-runtime-3.3.1.jar has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.hadoop_hadoop-client-runtime-3.3.1.jar
# 21/11/21 23:01:30 INFO Executor: Fetching spark://pyspark:40269/jars/org.apache.commons_commons-pool2-2.6.2.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO TransportClientFactory: Successfully created connection to pyspark/172.27.0.4:40269 after 47 ms (0 ms spent in bootstraps)
# 21/11/21 23:01:30 INFO Utils: Fetching spark://pyspark:40269/jars/org.apache.commons_commons-pool2-2.6.2.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp6123082544035352334.tmp
# 21/11/21 23:01:30 INFO Utils: /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp6123082544035352334.tmp has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.commons_commons-pool2-2.6.2.jar
# 21/11/21 23:01:30 INFO Executor: Adding file:/tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.commons_commons-pool2-2.6.2.jar to class loader
# 21/11/21 23:01:30 INFO Executor: Fetching spark://pyspark:40269/jars/org.apache.htrace_htrace-core4-4.1.0-incubating.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: Fetching spark://pyspark:40269/jars/org.apache.htrace_htrace-core4-4.1.0-incubating.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp13740440663434482428.tmp
# 21/11/21 23:01:30 INFO Utils: /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp13740440663434482428.tmp has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.htrace_htrace-core4-4.1.0-incubating.jar
# 21/11/21 23:01:30 INFO Executor: Adding file:/tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.htrace_htrace-core4-4.1.0-incubating.jar to class loader
# 21/11/21 23:01:30 INFO Executor: Fetching spark://pyspark:40269/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.2.0.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: Fetching spark://pyspark:40269/jars/org.apache.spark_spark-sql-kafka-0-10_2.12-3.2.0.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp17970799336914180320.tmp
# 21/11/21 23:01:30 INFO Utils: /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp17970799336914180320.tmp has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.spark_spark-sql-kafka-0-10_2.12-3.2.0.jar
# 21/11/21 23:01:30 INFO Executor: Adding file:/tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.spark_spark-sql-kafka-0-10_2.12-3.2.0.jar to class loader
# 21/11/21 23:01:30 INFO Executor: Fetching spark://pyspark:40269/jars/com.google.code.findbugs_jsr305-3.0.0.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: Fetching spark://pyspark:40269/jars/com.google.code.findbugs_jsr305-3.0.0.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp1214855797524107837.tmp
# 21/11/21 23:01:30 INFO Utils: /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp1214855797524107837.tmp has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/com.google.code.findbugs_jsr305-3.0.0.jar
# 21/11/21 23:01:30 INFO Executor: Adding file:/tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/com.google.code.findbugs_jsr305-3.0.0.jar to class loader
# 21/11/21 23:01:30 INFO Executor: Fetching spark://pyspark:40269/jars/org.apache.hadoop_hadoop-client-api-3.3.1.jar with timestamp 1637535687518
# 21/11/21 23:01:30 INFO Utils: Fetching spark://pyspark:40269/jars/org.apache.hadoop_hadoop-client-api-3.3.1.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp10124244629264013462.tmp
# 21/11/21 23:01:30 INFO Utils: /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp10124244629264013462.tmp has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.hadoop_hadoop-client-api-3.3.1.jar
# 21/11/21 23:01:31 INFO Executor: Adding file:/tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.hadoop_hadoop-client-api-3.3.1.jar to class loader
# 21/11/21 23:01:31 INFO Executor: Fetching spark://pyspark:40269/jars/org.spark-project.spark_unused-1.0.0.jar with timestamp 1637535687518
# 21/11/21 23:01:31 INFO Utils: Fetching spark://pyspark:40269/jars/org.spark-project.spark_unused-1.0.0.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp11726820300962909866.tmp
# 21/11/21 23:01:31 INFO Utils: /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp11726820300962909866.tmp has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.spark-project.spark_unused-1.0.0.jar
# 21/11/21 23:01:31 INFO Executor: Adding file:/tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.spark-project.spark_unused-1.0.0.jar to class loader
# 21/11/21 23:01:31 INFO Executor: Fetching spark://pyspark:40269/jars/org.apache.hadoop_hadoop-client-runtime-3.3.1.jar with timestamp 1637535687518
# 21/11/21 23:01:31 INFO Utils: Fetching spark://pyspark:40269/jars/org.apache.hadoop_hadoop-client-runtime-3.3.1.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp1178729328139561834.tmp
# 21/11/21 23:01:31 INFO Utils: /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp1178729328139561834.tmp has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.hadoop_hadoop-client-runtime-3.3.1.jar
# 21/11/21 23:01:33 INFO Executor: Adding file:/tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.hadoop_hadoop-client-runtime-3.3.1.jar to class loader
# 21/11/21 23:01:33 INFO Executor: Fetching spark://pyspark:40269/jars/org.slf4j_slf4j-api-1.7.30.jar with timestamp 1637535687518
# 21/11/21 23:01:33 INFO Utils: Fetching spark://pyspark:40269/jars/org.slf4j_slf4j-api-1.7.30.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp2078522363005941147.tmp
# 21/11/21 23:01:33 INFO Utils: /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp2078522363005941147.tmp has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.slf4j_slf4j-api-1.7.30.jar
# 21/11/21 23:01:33 INFO Executor: Adding file:/tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.slf4j_slf4j-api-1.7.30.jar to class loader
# 21/11/21 23:01:33 INFO Executor: Fetching spark://pyspark:40269/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar with timestamp 1637535687518
# 21/11/21 23:01:33 INFO Utils: Fetching spark://pyspark:40269/jars/org.xerial.snappy_snappy-java-1.1.8.4.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp10733934144826560149.tmp
# 21/11/21 23:01:33 INFO Utils: /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp10733934144826560149.tmp has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.xerial.snappy_snappy-java-1.1.8.4.jar
# 21/11/21 23:01:33 INFO Executor: Adding file:/tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.xerial.snappy_snappy-java-1.1.8.4.jar to class loader
# 21/11/21 23:01:33 INFO Executor: Fetching spark://pyspark:40269/jars/org.apache.kafka_kafka-clients-2.8.0.jar with timestamp 1637535687518
# 21/11/21 23:01:33 INFO Utils: Fetching spark://pyspark:40269/jars/org.apache.kafka_kafka-clients-2.8.0.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp13516089469288718741.tmp
# 21/11/21 23:01:33 INFO Utils: /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp13516089469288718741.tmp has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.kafka_kafka-clients-2.8.0.jar
# 21/11/21 23:01:33 INFO Executor: Adding file:/tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.kafka_kafka-clients-2.8.0.jar to class loader
# 21/11/21 23:01:33 INFO Executor: Fetching spark://pyspark:40269/jars/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.2.0.jar with timestamp 1637535687518
# 21/11/21 23:01:33 INFO Utils: Fetching spark://pyspark:40269/jars/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.2.0.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp6464785279960159784.tmp
# 21/11/21 23:01:33 INFO Utils: /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp6464785279960159784.tmp has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.2.0.jar
# 21/11/21 23:01:33 INFO Executor: Adding file:/tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.apache.spark_spark-token-provider-kafka-0-10_2.12-3.2.0.jar to class loader
# 21/11/21 23:01:33 INFO Executor: Fetching spark://pyspark:40269/jars/commons-logging_commons-logging-1.1.3.jar with timestamp 1637535687518
# 21/11/21 23:01:33 INFO Utils: Fetching spark://pyspark:40269/jars/commons-logging_commons-logging-1.1.3.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp8467562999017915600.tmp
# 21/11/21 23:01:33 INFO Utils: /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp8467562999017915600.tmp has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/commons-logging_commons-logging-1.1.3.jar
# 21/11/21 23:01:33 INFO Executor: Adding file:/tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/commons-logging_commons-logging-1.1.3.jar to class loader
# 21/11/21 23:01:33 INFO Executor: Fetching spark://pyspark:40269/jars/org.lz4_lz4-java-1.7.1.jar with timestamp 1637535687518
# 21/11/21 23:01:33 INFO Utils: Fetching spark://pyspark:40269/jars/org.lz4_lz4-java-1.7.1.jar to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp14498245562228348096.tmp
# 21/11/21 23:01:33 INFO Utils: /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/fetchFileTemp14498245562228348096.tmp has been previously copied to /tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.lz4_lz4-java-1.7.1.jar
# 21/11/21 23:01:33 INFO Executor: Adding file:/tmp/spark-02ecdafe-9f54-4792-9c68-3841884c60c0/userFiles-59a8da60-9b5c-4fb3-b2df-784f61db4948/org.lz4_lz4-java-1.7.1.jar to class loader
# 21/11/21 23:01:33 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 43837.
# 21/11/21 23:01:33 INFO NettyBlockTransferService: Server created on pyspark:43837
# 21/11/21 23:01:33 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 21/11/21 23:01:33 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, pyspark, 43837, None)
# 21/11/21 23:01:33 INFO BlockManagerMasterEndpoint: Registering block manager pyspark:43837 with 434.4 MiB RAM, BlockManagerId(driver, pyspark, 43837, None)
# 21/11/21 23:01:33 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, pyspark, 43837, None)
# 21/11/21 23:01:33 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, pyspark, 43837, None)
# 21/11/21 23:01:34 INFO SharedState: Setting hive.metastore.warehouse.dir ('null') to the value of spark.sql.warehouse.dir.
# 21/11/21 23:01:34 INFO SharedState: Warehouse path is 'file:/home/jovyan/spark-warehouse'.
# <pyspark.sql.session.SparkSession object at 0x7f457529be20>

# %%
# Importing data from kafka topic into spark data frame


readDF = spark \
.readStream \
.format("kafka") \
.option("kafka.bootstrap.servers","broker:29092") \
.option("subscribe","newtopic") \
.option("startingOffsets","earliest") \
.load() \
.selectExpr("CAST(value AS STRING)")

# %%
# Zip=601,Latitude=18.18005,Longitude=-66.75218,City=Adjuntas,State_ID=PR,State_Name=Puerto Rico,Population=17113.0,Population_Density=102.7,County_Code=72001}

# %%
# Importing sql funtion adn types library for type casting and split function

from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
readDF.printSchema()
# Out:
# root
#  |-- value: string (nullable = true)

# %%
print(type(readDF))
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
# Defining the schema and changing the values from json to struct format for processing in SQL, as it uses SQL Struct types

from pyspark.sql.functions import from_json, col
from pyspark.sql.types import StructType, StructField, StringType

schema = StructType(
    [
        StructField('Zip', StringType(), True),
        StructField('Latitude', StringType(), True),
        StructField('Longitude', StringType(), True),
        StructField('City', StringType(), True),
        StructField('State_ID', StringType(), True),
        StructField('State_Name', StringType(), True),
        StructField('Population', StringType(), True),
        StructField('Population_Density', StringType(), True),
        StructField('County_Code', StringType(), True)
    ]
)

readDF.withColumn("value", from_json("value", schema))\
    .select(col('value.*'))
# Out:
# DataFrame[Zip: string, Latitude: string, Longitude: string, City: string, State_ID: string, State_Name: string, Population: string, Population_Density: string, County_Code: string]

# %%
readDF.printSchema()
# Out:
# root
#  |-- value: string (nullable = true)

# %%
# values are like this at this point of time Struct{Zip=601,Latitude=18.18005....}
# Seaparting the values using "," here

newDF= readDF.withColumn("Zip", split(col("value"), ",").getItem(0))\
.withColumn("Latitude", split(col("value"), ",").getItem(1))\
.withColumn("Longitude", split(col("value"), ",").getItem(2))\
.withColumn("City", split(col("value"), ",").getItem(3))\
.withColumn("State_ID", split(col("value"), ",").getItem(4))\
.withColumn("State_Name", split(col("value"), ",").getItem(5))\
.withColumn("Population", split(col("value"), ",").getItem(6))\
.withColumn("Population_Density", split(col("value"), ",").getItem(7))\
.withColumn("County_Code", split(col("value"), ",").getItem(8))

# %%
# values are like this Struct{Zip=601 | Latitude=18.18005 |........}
# Separating the value using "=" to get the desired value

DF = newDF.withColumn("Zip", split(col("Zip"), "=").getItem(1))\
.withColumn("Latitude", split(col("Latitude"), "=").getItem(1))\
.withColumn("Longitude", split(col("Longitude"), "=").getItem(1))\
.withColumn("City", split(col("City"), "=").getItem(1))\
.withColumn("State_ID", split(col("State_ID"), "=").getItem(1))\
.withColumn("State_Name", split(col("State_Name"), "=").getItem(1))\
.withColumn("Population", split(col("Population"), "=").getItem(1))\
.withColumn("Population_Density", split(col("Population_Density"), "=").getItem(1))\
.withColumn("County_Code", split(col("County_Code"), "=").getItem(1))\
.withColumn("County_Code", split(col("County_Code"), "}").getItem(0)) #This because of the } in each value in this column at the end

# %%
DF.printSchema()
# Out:
# root
#  |-- value: string (nullable = true)
#  |-- Zip: string (nullable = true)
#  |-- Latitude: string (nullable = true)
#  |-- Longitude: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State_ID: string (nullable = true)
#  |-- State_Name: string (nullable = true)
#  |-- Population: string (nullable = true)
#  |-- Population_Density: string (nullable = true)
#  |-- County_Code: string (nullable = true)

# %%
finalDF = DF.select("Zip","Latitude","Longitude","City","State_ID","State_Name","Population","Population_Density","County_Code")

# %%
# finalDF = DF.selectExpr("CAST(Zip AS STRING)",\
#                    "CAST(Latitude AS STRING)",\
#                    "CAST(Longitude AS STRING)",\
#                    "CAST(City AS STRING)",\
#                    "CAST(State_ID AS STRING)",\
#                    "CAST(State_Name AS STRING)",\
#                    "CAST(Population AS STRING)",\
#                    "CAST(Population_Density AS STRING)",\
#                    "CAST(County_Code AS STRING)")

# %%
finalDF.printSchema()
# Out:
# root
#  |-- Zip: string (nullable = true)
#  |-- Latitude: string (nullable = true)
#  |-- Longitude: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State_ID: string (nullable = true)
#  |-- State_Name: string (nullable = true)
#  |-- Population: string (nullable = true)
#  |-- Population_Density: string (nullable = true)
#  |-- County_Code: string (nullable = true)

# %%
resultDF = finalDF \
.writeStream \
.format("console") \
.outputMode("append") \
.option("checkpointLocation", "checkpoint/")\
.option("truncate", "false")\
.option("numRows",20) \
.start().awaitTermination()
# Out:
# 21/11/21 23:04:31 INFO StateStoreCoordinatorRef: Registered StateStoreCoordinator endpoint
# 21/11/21 23:04:31 INFO ResolveWriteToStream: Checkpoint root checkpoint resolved to file:/home/jovyan/checkpoint.
# 21/11/21 23:04:31 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 21/11/21 23:04:31 INFO MicroBatchExecution: Starting [id = de6b4713-0636-43b2-8a54-ddd329944eb8, runId = 0ac98023-713c-4bfe-8e9c-5d158a4badc9]. Use file:/home/jovyan/checkpoint to store the query checkpoint.
# 21/11/21 23:04:31 INFO MicroBatchExecution: Reading table [org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@4c77f088] from DataSourceV2 named 'kafka' [org.apache.spark.sql.kafka010.KafkaSourceProvider@1a228222]
# 21/11/21 23:04:31 INFO MicroBatchExecution: Resuming at batch 8 with committed offsets {KafkaV2[Subscribe[newtopic]]: {"newtopic":{"0":264968}}} and available offsets {KafkaV2[Subscribe[newtopic]]: {"newtopic":{"0":264968}}}
# 21/11/21 23:04:31 INFO MicroBatchExecution: Stream started from {KafkaV2[Subscribe[newtopic]]: {"newtopic":{"0":264968}}}
# 21/11/21 23:04:31 INFO ConsumerConfig: ConsumerConfig values:
# 	allow.auto.create.topics = true
# 	auto.commit.interval.ms = 5000
# 	auto.offset.reset = earliest
# 	bootstrap.servers = [broker:29092]
# 	check.crcs = true
# 	client.dns.lookup = use_all_dns_ips
# 	client.id = consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1
# 	client.rack =
# 	connections.max.idle.ms = 540000
# 	default.api.timeout.ms = 60000
# 	enable.auto.commit = false
# 	exclude.internal.topics = true
# 	fetch.max.bytes = 52428800
# 	fetch.max.wait.ms = 500
# 	fetch.min.bytes = 1
# 	group.id = spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0
# 	group.instance.id = null
# 	heartbeat.interval.ms = 3000
# 	interceptor.classes = []
# 	internal.leave.group.on.close = true
# 	internal.throw.on.fetch.stable.offset.unsupported = false
# 	isolation.level = read_uncommitted
# 	key.deserializer = class org.apache.kafka.common.serialization.ByteArrayDeserializer
# 	max.partition.fetch.bytes = 1048576
# 	max.poll.interval.ms = 300000
# 	max.poll.records = 1
# 	metadata.max.age.ms = 300000
# 	metric.reporters = []
# 	metrics.num.samples = 2
# 	metrics.recording.level = INFO
# 	metrics.sample.window.ms = 30000
# 	partition.assignment.strategy = [class org.apache.kafka.clients.consumer.RangeAssignor]
# 	receive.buffer.bytes = 65536
# 	reconnect.backoff.max.ms = 1000
# 	reconnect.backoff.ms = 50
# 	request.timeout.ms = 30000
# 	retry.backoff.ms = 100
# 	sasl.client.callback.handler.class = null
# 	sasl.jaas.config = null
# 	sasl.kerberos.kinit.cmd = /usr/bin/kinit
# 	sasl.kerberos.min.time.before.relogin = 60000
# 	sasl.kerberos.service.name = null
# 	sasl.kerberos.ticket.renew.jitter = 0.05
# 	sasl.kerberos.ticket.renew.window.factor = 0.8
# 	sasl.login.callback.handler.class = null
# 	sasl.login.class = null
# 	sasl.login.refresh.buffer.seconds = 300
# 	sasl.login.refresh.min.period.seconds = 60
# 	sasl.login.refresh.window.factor = 0.8
# 	sasl.login.refresh.window.jitter = 0.05
# 	sasl.mechanism = GSSAPI
# 	security.protocol = PLAINTEXT
# 	security.providers = null
# 	send.buffer.bytes = 131072
# 	session.timeout.ms = 10000
# 	socket.connection.setup.timeout.max.ms = 30000
# 	socket.connection.setup.timeout.ms = 10000
# 	ssl.cipher.suites = null
# 	ssl.enabled.protocols = [TLSv1.2, TLSv1.3]
# 	ssl.endpoint.identification.algorithm = https
# 	ssl.engine.factory.class = null
# 	ssl.key.password = null
# 	ssl.keymanager.algorithm = SunX509
# 	ssl.keystore.certificate.chain = null
# 	ssl.keystore.key = null
# 	ssl.keystore.location = null
# 	ssl.keystore.password = null
# 	ssl.keystore.type = JKS
# 	ssl.protocol = TLSv1.3
# 	ssl.provider = null
# 	ssl.secure.random.implementation = null
# 	ssl.trustmanager.algorithm = PKIX
# 	ssl.truststore.certificates = null
# 	ssl.truststore.location = null
# 	ssl.truststore.password = null
# 	ssl.truststore.type = JKS
# 	value.deserializer = class org.apache.kafka.common.serialization.ByteArrayDeserializer
#
# 21/11/21 23:04:31 INFO AppInfoParser: Kafka version: 2.8.0
# 21/11/21 23:04:31 INFO AppInfoParser: Kafka commitId: ebb1d6e21cc92130
# 21/11/21 23:04:31 INFO AppInfoParser: Kafka startTimeMs: 1637535871963
# 21/11/21 23:04:31 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Subscribed to topic(s): newtopic
# 21/11/21 23:04:32 INFO Metadata: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Cluster ID: ieGoeAVVQdGGFUn2k-P1JQ
# 21/11/21 23:04:32 INFO AbstractCoordinator: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Discovered group coordinator broker:29092 (id: 2147483646 rack: null)
# 21/11/21 23:04:32 INFO AbstractCoordinator: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] (Re-)joining group
# 21/11/21 23:04:32 INFO AbstractCoordinator: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] (Re-)joining group
# 21/11/21 23:04:32 INFO AbstractCoordinator: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Successfully joined group with generation Generation{generationId=1, memberId='consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1-e555e915-01c3-44fb-8a9d-9e82a13352c9', protocol='range'}
# 21/11/21 23:04:32 INFO ConsumerCoordinator: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Finished assignment for group at generation 1: {consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1-e555e915-01c3-44fb-8a9d-9e82a13352c9=Assignment(partitions=[newtopic-0])}
# 21/11/21 23:04:32 INFO AbstractCoordinator: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Successfully synced group in generation Generation{generationId=1, memberId='consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1-e555e915-01c3-44fb-8a9d-9e82a13352c9', protocol='range'}
# 21/11/21 23:04:32 INFO ConsumerCoordinator: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Notifying assignor about the new Assignment(partitions=[newtopic-0])
# 21/11/21 23:04:32 INFO ConsumerCoordinator: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Adding newly assigned partitions: newtopic-0
# 21/11/21 23:04:32 INFO ConsumerCoordinator: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Found no committed offset for partition newtopic-0
# 21/11/21 23:04:32 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:32 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:32 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:32 INFO CheckpointFileManager: Writing atomically to file:/home/jovyan/checkpoint/offsets/8 using temp file file:/home/jovyan/checkpoint/offsets/.8.f92c94e8-ad18-4aab-9d91-0777ad33c964.tmp
# 21/11/21 23:04:32 INFO CheckpointFileManager: Renamed temp file file:/home/jovyan/checkpoint/offsets/.8.f92c94e8-ad18-4aab-9d91-0777ad33c964.tmp to file:/home/jovyan/checkpoint/offsets/8
# 21/11/21 23:04:32 INFO MicroBatchExecution: Committed offsets for batch 8. Metadata OffsetSeqMetadata(0,1637535872879,Map(spark.sql.streaming.stateStore.providerClass -> org.apache.spark.sql.execution.streaming.state.HDFSBackedStateStoreProvider, spark.sql.streaming.join.stateFormatVersion -> 2, spark.sql.streaming.stateStore.compression.codec -> lz4, spark.sql.streaming.stateStore.rocksdb.formatVersion -> 5, spark.sql.streaming.flatMapGroupsWithState.stateFormatVersion -> 2, spark.sql.streaming.multipleWatermarkPolicy -> min, spark.sql.streaming.aggregation.stateFormatVersion -> 2, spark.sql.shuffle.partitions -> 200))
# 21/11/21 23:04:33 INFO KafkaOffsetReaderConsumer: Partitions added: Map()
# 21/11/21 23:04:33 INFO KafkaOffsetReaderConsumer: Partitions added: Map()
# 21/11/21 23:04:34 INFO KafkaOffsetReaderConsumer: Partitions added: Map()
# 21/11/21 23:04:34 INFO KafkaOffsetReaderConsumer: Partitions added: Map()
# 21/11/21 23:04:34 INFO KafkaOffsetReaderConsumer: Partitions added: Map()
# 21/11/21 23:04:34 INFO KafkaOffsetReaderConsumer: Partitions added: Map()
# 21/11/21 23:04:35 INFO CodeGenerator: Code generated in 554.2938 ms
# 21/11/21 23:04:35 INFO WriteToDataSourceV2Exec: Start processing data source write support: org.apache.spark.sql.execution.streaming.sources.MicroBatchWrite@588b2983. The input RDD has 1 partitions.
# 21/11/21 23:04:35 INFO SparkContext: Starting job: start at NativeMethodAccessorImpl.java:0
# 21/11/21 23:04:35 INFO DAGScheduler: Got job 0 (start at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 21/11/21 23:04:35 INFO DAGScheduler: Final stage: ResultStage 0 (start at NativeMethodAccessorImpl.java:0)
# 21/11/21 23:04:35 INFO DAGScheduler: Parents of final stage: List()
# 21/11/21 23:04:35 INFO DAGScheduler: Missing parents: List()
# 21/11/21 23:04:35 INFO DAGScheduler: Submitting ResultStage 0 (MapPartitionsRDD[2] at start at NativeMethodAccessorImpl.java:0), which has no missing parents
# 21/11/21 23:04:35 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 21.9 KiB, free 434.4 MiB)
# 21/11/21 23:04:36 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 7.0 KiB, free 434.4 MiB)
# 21/11/21 23:04:36 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on pyspark:43837 (size: 7.0 KiB, free: 434.4 MiB)
# 21/11/21 23:04:36 INFO SparkContext: Created broadcast 0 from broadcast at DAGScheduler.scala:1427
# 21/11/21 23:04:36 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 0 (MapPartitionsRDD[2] at start at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 21/11/21 23:04:36 INFO TaskSchedulerImpl: Adding task set 0.0 with 1 tasks resource profile 0
# 21/11/21 23:04:36 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0) (pyspark, executor driver, partition 0, PROCESS_LOCAL, 5291 bytes) taskResourceAssignments Map()
# 21/11/21 23:04:36 INFO Executor: Running task 0.0 in stage 0.0 (TID 0) + 0) / 1]
# 21/11/21 23:04:36 INFO CodeGenerator: Code generated in 78.1977 ms  (0 + 1) / 1]
# 21/11/21 23:04:36 INFO CodeGenerator: Code generated in 97.6741 ms
# 21/11/21 23:04:36 INFO ConsumerConfig: ConsumerConfig values:
# 	allow.auto.create.topics = true
# 	auto.commit.interval.ms = 5000
# 	auto.offset.reset = none
# 	bootstrap.servers = [broker:29092]
# 	check.crcs = true
# 	client.dns.lookup = use_all_dns_ips
# 	client.id = consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2
# 	client.rack =
# 	connections.max.idle.ms = 540000
# 	default.api.timeout.ms = 60000
# 	enable.auto.commit = false
# 	exclude.internal.topics = true
# 	fetch.max.bytes = 52428800
# 	fetch.max.wait.ms = 500
# 	fetch.min.bytes = 1
# 	group.id = spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor
# 	group.instance.id = null
# 	heartbeat.interval.ms = 3000
# 	interceptor.classes = []
# 	internal.leave.group.on.close = true
# 	internal.throw.on.fetch.stable.offset.unsupported = false
# 	isolation.level = read_uncommitted
# 	key.deserializer = class org.apache.kafka.common.serialization.ByteArrayDeserializer
# 	max.partition.fetch.bytes = 1048576
# 	max.poll.interval.ms = 300000
# 	max.poll.records = 500
# 	metadata.max.age.ms = 300000
# 	metric.reporters = []
# 	metrics.num.samples = 2
# 	metrics.recording.level = INFO
# 	metrics.sample.window.ms = 30000
# 	partition.assignment.strategy = [class org.apache.kafka.clients.consumer.RangeAssignor]
# 	receive.buffer.bytes = 65536
# 	reconnect.backoff.max.ms = 1000
# 	reconnect.backoff.ms = 50
# 	request.timeout.ms = 30000
# 	retry.backoff.ms = 100
# 	sasl.client.callback.handler.class = null
# 	sasl.jaas.config = null
# 	sasl.kerberos.kinit.cmd = /usr/bin/kinit
# 	sasl.kerberos.min.time.before.relogin = 60000
# 	sasl.kerberos.service.name = null
# 	sasl.kerberos.ticket.renew.jitter = 0.05
# 	sasl.kerberos.ticket.renew.window.factor = 0.8
# 	sasl.login.callback.handler.class = null
# 	sasl.login.class = null
# 	sasl.login.refresh.buffer.seconds = 300
# 	sasl.login.refresh.min.period.seconds = 60
# 	sasl.login.refresh.window.factor = 0.8
# 	sasl.login.refresh.window.jitter = 0.05
# 	sasl.mechanism = GSSAPI
# 	security.protocol = PLAINTEXT
# 	security.providers = null
# 	send.buffer.bytes = 131072
# 	session.timeout.ms = 10000
# 	socket.connection.setup.timeout.max.ms = 30000
# 	socket.connection.setup.timeout.ms = 10000
# 	ssl.cipher.suites = null
# 	ssl.enabled.protocols = [TLSv1.2, TLSv1.3]
# 	ssl.endpoint.identification.algorithm = https
# 	ssl.engine.factory.class = null
# 	ssl.key.password = null
# 	ssl.keymanager.algorithm = SunX509
# 	ssl.keystore.certificate.chain = null
# 	ssl.keystore.key = null
# 	ssl.keystore.location = null
# 	ssl.keystore.password = null
# 	ssl.keystore.type = JKS
# 	ssl.protocol = TLSv1.3
# 	ssl.provider = null
# 	ssl.secure.random.implementation = null
# 	ssl.trustmanager.algorithm = PKIX
# 	ssl.truststore.certificates = null
# 	ssl.truststore.location = null
# 	ssl.truststore.password = null
# 	ssl.truststore.type = JKS
# 	value.deserializer = class org.apache.kafka.common.serialization.ByteArrayDeserializer
#
# 21/11/21 23:04:36 INFO AppInfoParser: Kafka version: 2.8.0
# 21/11/21 23:04:36 INFO AppInfoParser: Kafka commitId: ebb1d6e21cc92130
# 21/11/21 23:04:36 INFO AppInfoParser: Kafka startTimeMs: 1637535876939
# 21/11/21 23:04:36 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Subscribed to partition(s): newtopic-0
# 21/11/21 23:04:36 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 264968 for partition newtopic-0
# 21/11/21 23:04:36 INFO Metadata: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Cluster ID: ieGoeAVVQdGGFUn2k-P1JQ
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 265468 for partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 265968 for partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 266468 for partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 266968 for partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 267468 for partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 267968 for partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 268030 for partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 268530 for partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 269030 for partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 269530 for partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 270030 for partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:37 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:38 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 270530 for partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:38 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 271030 for partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:38 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 271053 for partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:38 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 271553 for partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:38 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 272053 for partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:38 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 272553 for partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:38 INFO KafkaConsumer: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to offset 273053 for partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Seeking to EARLIEST offset of partition newtopic-0
# 21/11/21 23:04:38 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor-2, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-executor] Resetting offset for partition newtopic-0 to position FetchPosition{offset=0, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# ...
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to pos
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2836/3968562073.py in <module>
# ----> 1 resultDF = finalDF \
#       2 .writeStream \
#       3 .format("console") \
#       4 .outputMode("append") \
#       5 .option("checkpointLocation", "checkpoint/")\
#
# /usr/local/spark/python/pyspark/sql/streaming.py in awaitTermination(self, timeout)
#      99             return self._jsq.awaitTermination(int(timeout * 1000))
#     100         else:
# --> 101             return self._jsq.awaitTermination()
#     102
#     103     @property
#
# /usr/local/spark/python/lib/py4j-0.10.9.2-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1306             proto.END_COMMAND_PART
#    1307
# -> 1308         answer = self.gateway_client.send_command(command)
#    1309         return_value = get_return_value(
#    1310             answer, self.gateway_client, self.target_id, self.name)
#
# /usr/local/spark/python/lib/py4j-0.10.9.2-src.zip/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1036         connection = self._get_connection()
#    1037         try:
# -> 1038             response = connection.send_command(command)
#    1039             if binary:
#    1040                 return response, self._create_connection_guard(connection)
#
# /usr/local/spark/python/lib/py4j-0.10.9.2-src.zip/py4j/clientserver.py in send_command(self, command)
#     473         try:
#     474             while True:
# --> 475                 answer = smart_decode(self.stream.readline()[:-1])
#     476                 logger.debug("Answer received: {0}".format(answer))
#     477                 # Happens when a the other end is dead. There might be an empty
#
# /opt/conda/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:
# ition FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Seeking to LATEST offset of partition newtopic-0
# 21/11/21 23:04:50 INFO SubscriptionState: [Consumer clientId=consumer-spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0-1, groupId=spark-kafka-source-d9988708-2040-4d0c-a1b9-4fc3d3d5151e--587948755-driver-0] Resetting offset for partition newtopic-0 to position FetchPosition{offset=298089, offsetEpoch=Optional.empty, currentLeader=LeaderAndEpoch{leader=Optional[broker:29092 (id: 1 rack: null)], epoch=0}}.
